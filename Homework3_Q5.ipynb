# %% [markdown]
# <a href="https://colab.research.google.com/github/kaushik67/ceri8211globalgeophysics/blob/master/Homework3_Q5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Sr_Sr = np.array([0.7117,0.7095,0.7092,0.7083,0.7083,0.7082]) #87Sr/86Sr ratio
Rb_Sr = np.array([3.65,1.80,1.48,0.82,0.66,0.74]) #87Rb/86Sr ratio
z = np.polyfit(Rb_Sr,Sr_Sr, 1)
p = np.poly1d(z)

# %%
fig = plt.figure(figsize=(8,8))
xp = np.linspace(0, 6, 1000)

plt.plot(Rb_Sr , Sr_Sr, 'bo',label = 'Rb-Sr isochron data point')
_ = plt.plot(Rb_Sr, Sr_Sr, '.', xp, p(xp), 'r-')
plt.legend(loc='best')

plt.ylabel('87Sr/86Sr')
plt.xlabel('87Rb/86Sr')
plt.title('Rb-Sr isochron')
print(p)
# Out:
#
# 0.001176 x + 0.7074
